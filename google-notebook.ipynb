# %% [markdown]
# # **GOOGLE DATASET**

# %% [markdown]
# # **IMPORTS**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %% [markdown]
# # **IMPORTING THE DATA SET AND DEFINING ITS DIMENSIONS**

# %%
google_data = pd.read_csv('../input/google-play-store-apps/googleplaystore.csv')

nRow, nCol = google_data.shape
print(f'There are {nRow} rows and {nCol} columns')

# %% [markdown]
# # **GATHERING THE AMOUNT OF DATA POINTS AND VARIABLE TYPES**

# %%
google_data.info()

# %% [markdown]
# # **DESCRIBING THE RATING**

# %%
google_data.describe()

# %% [markdown]
# # **CHECKING FOR OUTLIERS USING BOXPLOT AND HISTOGRAM**

# %%
google_data.boxplot()

# %%
google_data.hist()

# %% [markdown]
# **Based on the histograms maximum value and the boxplot's horizontal range, we know there is a rating value that is greater than 5. We that since the max of the boxplot is above 17.5, there is an outlier cleaned out of the data.**

# %% [markdown]
# # **CHECKING THE AMOUNT OF NULL VALUES**

# %%
google_data.isnull().sum()

# %% [markdown]
# # **CHECK FOR RATING VALUES GREATER THAN 5**

# %%
google_data[google_data.Rating > 5]

# %%
google_data.drop(10472,inplace=True)

# %%
google_data[google_data.Rating > 5]
